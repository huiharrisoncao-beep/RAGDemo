# %%
import os, subprocess
os.makedirs('/Users/harrisoncao/Workspace/RAGDemo.worktrees/graphrag-knowledge-sharing-demo', exist_ok=True)
REPO='/Users/harrisoncao/Workspace/RAGDemo'
def g(*a):
    r=subprocess.run(['git','-C',REPO,*a],capture_output=True,text=True)
    print('$ git',*a,'\n',r.stdout,r.stderr)
g('worktree','prune')
g('branch','-d','agents/graphrag-knowledge-sharing-demo')
g('branch','-a')
g('worktree','list')
